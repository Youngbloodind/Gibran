# %% [markdown]
# Menghitung jumlah detik dalam sehari atau 24 jam

# %%
jumlah_detik_dalam_sehari = 24 * 60 * 60
jumlah_detik_dalam_sehari
# Out:
# 86400

# %%
nama_mhs1 = "Gibran Akhsya Aulika"
nama_mhs2 = "Al Raffi Akbar"
print(nama_mhs1, "dan", nama_mhs2, "adalah mahasiswa TRKJ\nFakultas Teknik Industri, Universitas Bung Hatta")
# Out:
# Gibran Akhsya Aulika dan Al Raffi Akbar adalah mahasiswa TRKJ
# Fakultas Teknik Industri, Universitas Bung Hatta
